# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Import dataset

# %%
dataset=pd.read_csv('adult_with_headers.csv')
dataset
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# dataset.describe()

# %%
dataset.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# income            object
# dtype: object

# %%
dataset.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %% [markdown]
# ### Standard Scaler

# %%
numf=dataset.select_dtypes(include=['int64']).columns

# %%
scaler = StandardScaler()

dataset[numf]= scaler.fit_transform(dataset[numf])
dataset
# Out:
#             age          workclass    fnlwgt    education  education_num  \
# 0      0.030671          State-gov -1.063611    Bachelors       1.134739
# 1      0.837109   Self-emp-not-inc -1.008707    Bachelors       1.134739
# 2     -0.042642            Private  0.245079      HS-grad      -0.420060
# 3      1.057047            Private  0.425801         11th      -1.197459
# 4     -0.775768            Private  1.408176    Bachelors       1.134739
# ...         ...                ...       ...          ...            ...
# 32556 -0.849080            Private  0.639741   Assoc-acdm       0.746039
# 32557  0.103983            Private -0.335433      HS-grad      -0.420060
# 32558  1.423610            Private -0.358777      HS-grad      -0.420060
# 32559 -1.215643            Private  0.110960      HS-grad      -0.420060
# 32560  0.983734       Self-emp-inc  0.929893      HS-grad      -0.420060
#
#             marital_status          occupation    relationship    race  \
# ...

# %% [markdown]
# ### Min Max Scaling

# %%
minmaxscaler = MinMaxScaler()

# %%
dataset[numf] = minmaxscaler.fit_transform(dataset[numf])
dataset
# Out:
#             age          workclass    fnlwgt    education  education_num  \
# 0      0.301370          State-gov  0.044302    Bachelors       0.800000
# 1      0.452055   Self-emp-not-inc  0.048238    Bachelors       0.800000
# 2      0.287671            Private  0.138113      HS-grad       0.533333
# 3      0.493151            Private  0.151068         11th       0.400000
# 4      0.150685            Private  0.221488    Bachelors       0.800000
# ...         ...                ...       ...          ...            ...
# 32556  0.136986            Private  0.166404   Assoc-acdm       0.733333
# 32557  0.315068            Private  0.096500      HS-grad       0.533333
# 32558  0.561644            Private  0.094827      HS-grad       0.533333
# 32559  0.068493            Private  0.128499      HS-grad       0.533333
# 32560  0.479452       Self-emp-inc  0.187203      HS-grad       0.533333
#
#             marital_status          occupation    relationship    race  \
# ...

# %% [markdown]
# •Discuss the scenarios where each scaling technique is preferred and why.
#
# 1. Standard Scaling (Z-score Normalization)
# Preferred when:
# Data is normally distributed or approximately normal.
# Features have different units or scales (e.g., age in years, income in dollars).
# Working with algorithms sensitive to distance or covariance (e.g., SVM, K-means, PCA).
# You don’t want to distort relationships between features.
# Why: Centers data around 0 with unit variance, ensuring features with larger magnitudes don't dominate.
#
# 2. Min-Max Scaling (Normalization)
# Preferred when:
# Data is not normally distributed or has outliers.
# You need features on a fixed range (e.g., [0, 1]), especially for neural networks or algorithms like KNN.
# Preserving relationships between features is important.
# Why: Scales features to a fixed range, ensuring the model treats all features equally, but sensitive to outliers.

# %% [markdown]
# # Encoding Techniques

# %%
unique_counts = dataset[['age','workclass','fnlwgt','education','education_num','marital_status','occupation','relationship','race','sex','capital_gain','capital_loss','hours_per_week','native_country','income']].nunique()
unique_counts
# Out:
# age                  73
# workclass             9
# fnlwgt            21648
# education            16
# education_num        16
# marital_status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital_gain        119
# capital_loss         92
# hours_per_week       94
# native_country       42
# income                2
# dtype: int64

# %% [markdown]
# ### One Hot Encoding

# %%
# Identify categorical columns with fewer than 5 unique categories
categorical_columns = dataset.select_dtypes(include=['object']).nunique()
columns_to_encode = categorical_columns[categorical_columns < 5].index

# Apply One-Hot Encoding to these columns
df_encoded = pd.get_dummies(dataset, columns=columns_to_encode, drop_first=False)

# Ensure output is in 0/1 format
df_encoded
# Out:
#             age          workclass    fnlwgt    education  education_num  \
# 0      0.301370          State-gov  0.044302    Bachelors       0.800000
# 1      0.452055   Self-emp-not-inc  0.048238    Bachelors       0.800000
# 2      0.287671            Private  0.138113      HS-grad       0.533333
# 3      0.493151            Private  0.151068         11th       0.400000
# 4      0.150685            Private  0.221488    Bachelors       0.800000
# ...         ...                ...       ...          ...            ...
# 32556  0.136986            Private  0.166404   Assoc-acdm       0.733333
# 32557  0.315068            Private  0.096500      HS-grad       0.533333
# 32558  0.561644            Private  0.094827      HS-grad       0.533333
# 32559  0.068493            Private  0.128499      HS-grad       0.533333
# 32560  0.479452       Self-emp-inc  0.187203      HS-grad       0.533333
#
#             marital_status          occupation    relationship    race  \
# ...

# %%
df_encoded.dtypes
# Out:
# age               float64
# workclass          object
# fnlwgt            float64
# education          object
# education_num     float64
# marital_status     object
# occupation         object
# relationship       object
# race               object
# capital_gain      float64
# capital_loss      float64
# hours_per_week    float64
# native_country     object
# sex_ Female          bool
# sex_ Male            bool
# income_ <=50K        bool
# income_ >50K         bool
# dtype: object

# %% [markdown]
# ### Label Encoder

# %%
# Identify categorical columns with more than 5 unique categories
categorical_columns = dataset.select_dtypes(include=['object']).nunique()
columns_to_encode = categorical_columns[categorical_columns > 5].index

# Apply Label Encoding to the selected columns
encoder = LabelEncoder()

# Label Encoding for each selected column
for column in columns_to_encode:
    dataset[column] = encoder.fit_transform(dataset[column])

# Display the DataFrame after Label Encoding
dataset
# Out:
#             age  workclass    fnlwgt  education  education_num  \
# 0      0.301370          7  0.044302          9       0.800000
# 1      0.452055          6  0.048238          9       0.800000
# 2      0.287671          4  0.138113         11       0.533333
# 3      0.493151          4  0.151068          1       0.400000
# 4      0.150685          4  0.221488          9       0.800000
# ...         ...        ...       ...        ...            ...
# 32556  0.136986          4  0.166404          7       0.733333
# 32557  0.315068          4  0.096500         11       0.533333
# 32558  0.561644          4  0.094827         11       0.533333
# 32559  0.068493          4  0.128499         11       0.533333
# 32560  0.479452          5  0.187203         11       0.533333
#
#        marital_status  occupation  relationship    race      sex  \
# 0                   4           1             1   White     Male
# 1                   2           4             0   White     Male
# ...

# %% [markdown]
# ### **One-Hot Encoding**
# **Pros**:
# - No implicit ordering, suitable for nominal data.
# - Works well for small to medium categories.
# - Prevents models from assuming category order.
#
# **Cons**:
# - Increases dimensionality, leading to sparse matrices.
# - Can be inefficient for high-cardinality features (many categories).
#
# **Best For**:
# - Nominal data (unordered categories).
# - Small to medium-sized categorical features.
#
# ### **Label Encoding**
# **Pros**:
# - Compact (uses one column).
# - Efficient for ordinal data (ordered categories).
# - Faster computation for large datasets.
#
# **Cons**:
# - Imposes an ordinal relationship on nominal data.
# - Can mislead models by implying order where none exists.
#
# **Best For**:
# - Ordinal data (ordered categories).
# - Large datasets with high-cardinality features.

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## (Education × Hours-Per-Week)

# %%
# Create the interaction feature
dataset['Education_Hours'] = dataset['education_num'] * dataset['hours_per_week']

# Preview the new feature
dataset[['education_num', 'hours_per_week', 'Education_Hours']].head()
# Out:
#    education_num  hours_per_week  Education_Hours
# 0       0.800000        0.397959         0.318367
# 1       0.800000        0.122449         0.097959
# 2       0.533333        0.397959         0.212245
# 3       0.400000        0.397959         0.159184
# 4       0.800000        0.397959         0.318367

# %% [markdown]
# Rationale: If you have features like education level and hours worked per week, their interaction could capture the combined effect of education and work effort on income.

# %% [markdown]
# ## (Income x Capital Ratio)

# %%
# Income-to-Capital Ratio (ICR)
# Add a small constant to avoid division by zero
dataset['ICR'] = (dataset['capital_gain'] - dataset['capital_loss']) / (dataset['fnlwgt'] + 1e-9)

# Display the first few rows with new features
dataset[['hours_per_week', 'relationship', 'capital_gain', 'capital_loss', 'fnlwgt', 'ICR']].head()
# Out:
#    hours_per_week  relationship  capital_gain  capital_loss    fnlwgt  \
# 0        0.397959             1       0.02174           0.0  0.044302
# 1        0.122449             0       0.00000           0.0  0.048238
# 2        0.397959             1       0.00000           0.0  0.138113
# 3        0.397959             0       0.00000           0.0  0.151068
# 4        0.397959             5       0.00000           0.0  0.221488
#
#         ICR
# 0  0.490729
# 1  0.000000
# 2  0.000000
# 3  0.000000
# 4  0.000000

# %% [markdown]
# Rationale: The *Income-to-Capital Ratio (ICR)* measures net capital gains relative to population representation (fnlwgt). It highlights financial security: positive values suggest wealthier individuals (higher income potential), while negative values indicate losses. Dividing by fnlwgt normalizes this metric, and a small constant prevents division errors.

# %% [markdown]
# ### Skewnwss

# %%
# Identify numerical columns
numerical_columns = dataset.select_dtypes(include=[np.number]).columns
print("Numerical columns:", numerical_columns)

# Check skewness
for col in numerical_columns:
    skewness = dataset[col].skew()
    print(f"Skewness of {col}: {skewness}")
# Out:
# Numerical columns: Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'capital_gain',
#        'capital_loss', 'hours_per_week', 'native_country', 'Education_Hours',
#        'ICR'],
#       dtype='object')
# Skewness of age: 0.5587433694130481
# Skewness of workclass: -0.7520240119541499
# Skewness of fnlwgt: 1.4469800945789812
# Skewness of education: -0.9340424374279611
# Skewness of education_num: -0.31167586791022756
# Skewness of marital_status: -0.01350813802823499
# Skewness of occupation: 0.11458331643295894
# Skewness of relationship: 0.7868177781306165
# Skewness of capital_gain: 11.953847687699781
# Skewness of capital_loss: 4.594629121679695
# Skewness of hours_per_week: 0.22764253680450075
# Skewness of native_country: -3.658303294717141
# Skewness of Education_Hours: 0.727857086156734
# Skewness of ICR: -3.085568991940199

# %% [markdown]
# The log transformation was applied to *capital_gain* because it had extremely high skewness (11.95). The transformation reduced the skewness, resulting in a more symmetric distribution, which improves model performance, interpretability, and statistical validity.

# %% [markdown]
# # Feature Selection

# %%
from sklearn.ensemble import IsolationForest

# %%
numfeats = dataset.select_dtypes(include=['int64', 'float64']).columns

# %%
# Applying Isolation Forest

isolation_forest = IsolationForest(contamination=0.01, random_state=42)
outliers = isolation_forest.fit_predict(dataset[numfeats])

# %%
dataset['outlier'] = outliers
print(dataset[['outlier']].value_counts())
# Out:
# outlier
#  1         32235
# -1           326
# Name: count, dtype: int64

# %%
# Filter out outliers

data_no_outliers = dataset[dataset['outlier'] == 1]
data_no_outliers
# Out:
#             age  workclass    fnlwgt  education  education_num  \
# 0      0.301370          7  0.044302          9       0.800000
# 1      0.452055          6  0.048238          9       0.800000
# 2      0.287671          4  0.138113         11       0.533333
# 3      0.493151          4  0.151068          1       0.400000
# 4      0.150685          4  0.221488          9       0.800000
# ...         ...        ...       ...        ...            ...
# 32556  0.136986          4  0.166404          7       0.733333
# 32557  0.315068          4  0.096500         11       0.533333
# 32558  0.561644          4  0.094827         11       0.533333
# 32559  0.068493          4  0.128499         11       0.533333
# 32560  0.479452          5  0.187203         11       0.533333
#
#        marital_status  occupation  relationship    race      sex  \
# 0                   4           1             1   White     Male
# 1                   2           4             0   White     Male
# ...

# %%
# View outliers only

outliers_only = dataset[dataset['outlier'] == -1]
outliers_only
# Out:
#             age  workclass    fnlwgt  education  education_num  \
# 52     0.410959          4  0.026861         14       0.933333
# 93     0.178082          4  0.071625         11       0.533333
# 106    0.000000          0  0.198712          0       0.333333
# 112    0.534247          6  0.219584         11       0.533333
# 157    0.739726          6  0.327310         15       0.600000
# ...         ...        ...       ...        ...            ...
# 32090  0.671233          4  0.070098          9       0.800000
# 32307  0.342466          5  0.121508          9       0.800000
# 32341  0.780822          6  0.126901          9       0.800000
# 32469  0.561644          5  0.115245         10       1.000000
# 32525  0.876712          0  0.073480          8       0.666667
#
#        marital_status  occupation  relationship                 race      sex  \
# 52                  2          10             5                White   Female
# ...

# %%
# Drop the 'outlier' column if it's no longer needed

data_no_outliers = data_no_outliers.drop(columns=['outlier'])

# %% [markdown]
# ### PPS Score

# %%
#!pip install pandas==1.5.3 ppscore --force-reinstall

# %%
# Install the necessary library for PPS computation
# !pip install ppscore --quiet

# Import the PPS library
import ppscore as pps

# Compute the PPS matrix for the dataset
pps_matrix = pps.matrix(data_no_outliers)

# Display the top 10 feature relationships with the highest PPS
pps_matrix[['x', 'y', 'ppscore']].sort_values(by='ppscore', ascending=False).head(10)
# Out:
#                    x                y  ppscore
# 288              ICR              ICR      1.0
# 270  Education_Hours  Education_Hours      1.0
# 18         workclass        workclass      1.0
# 252           income           income      1.0
# 234   native_country   native_country      1.0
# 216   hours_per_week   hours_per_week      1.0
# 198     capital_loss     capital_loss      1.0
# 180     capital_gain     capital_gain      1.0
# 162              sex              sex      1.0
# 144             race             race      1.0
