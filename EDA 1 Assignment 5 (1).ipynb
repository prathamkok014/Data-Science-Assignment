# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1.	Data Cleaning and Preparation:

# %%
df=pd.read_csv("Cardiotocographic.csv")
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
df.shape
# Out:
# (2126, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
int(df.isnull().sum().sum())
# Out:
# 167

# %%
# missing values in percent

df.isnull().sum()/df.shape[0]*100
# Out:
# LB          0.987770
# AC          0.940734
# FM          0.000000
# UC          0.000000
# DL          0.000000
# DS          0.987770
# DP          0.987770
# ASTV        0.000000
# MSTV        0.000000
# ALTV        0.000000
# MLTV        0.987770
# Width       0.987770
# Tendency    0.987770
# NSP         0.987770
# dtype: float64

# %%
## Handling Missing values

# %%
df['LB'].fillna(df['LB'].median(),inplace=True)

# %%
df['AC'].fillna(df['AC'].median(),inplace=True)

# %%
df['DS'].fillna(df['DS'].median(),inplace=True)

# %%
df['DP'].fillna(df['DP'].median(),inplace=True)

# %%
df['MLTV'].fillna(df['MLTV'].median(),inplace=True)

# %%
df['Width'].fillna(df['Width'].median(),inplace=True)

# %%
df['Tendency'].fillna(df['Tendency'].median(),inplace=True)

# %%
df['NSP'].fillna(df['NSP'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
## Finding Duplicated Value

# %%
int(df.duplicated().sum())
# Out:
# 2

# %%
df.drop_duplicates(inplace=True)

# %%
# droping Duplicated Value

int(df.duplicated().sum())
# Out:
# 0

# %%
df.drop(columns=['DS','DP','NSP'],inplace=True)
df.head()
# Out:
#            LB        AC   FM        UC        DL  ASTV  MSTV  ALTV  MLTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  73.0   0.5  43.0   2.4
# 1  132.000000  0.006380  0.0  0.006380  0.003190  17.0   2.1   0.0  10.4
# 2  133.000000  0.003322  0.0  0.008306  0.003322  16.0   2.1   0.0  13.4
# 3  134.000000  0.002561  0.0  0.007742  0.002561  16.0   2.4   0.0  23.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  16.0   2.4   0.0  19.9
#
#    Width  Tendency
# 0   64.0  0.999926
# 1  130.0  0.000000
# 2  130.0  0.000000
# 3  117.0  1.000000
# 4  117.0  1.000000

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
def outlier_Detection(df,columns):
    for col in columns:
        Q1=df[col].quantile(0.25)
        Q3=df[col].quantile(0.75)
        iqr=Q3-Q1
        lower=Q1-1.5*iqr
        upper=Q3+1.5*iqr
        df[col]=np.where(df[col]>upper,upper,np.where(df[col]<lower,lower,df[col]))
    return df

# %%
outlier_Detection(df,['LB','AC','FM','UC','DL','ASTV','MSTV','ALTV','MLTV','Width','Tendency'])
# Out:
#               LB        AC        FM        UC        DL  ASTV  MSTV  ALTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  73.0   0.5  27.5
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  17.0   2.1   0.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  16.0   2.1   0.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  16.0   2.4   0.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  16.0   2.4   0.0
# ...          ...       ...       ...       ...       ...   ...   ...   ...
# 2121  140.000000  0.000000  0.006421  0.007426  0.000000  79.0   0.2  25.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  78.0   0.4  22.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  79.0   0.4  20.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  78.0   0.4  27.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  74.0   0.4  27.5
#
#       MLTV  Width  Tendency
# 0      2.4   64.0  0.999926
# ...

# %%
outlier_Detection(df,['ALTV'])
# Out:
#               LB        AC        FM        UC        DL  ASTV  MSTV  ALTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  73.0   0.5  27.5
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  17.0   2.1   0.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  16.0   2.1   0.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  16.0   2.4   0.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  16.0   2.4   0.0
# ...          ...       ...       ...       ...       ...   ...   ...   ...
# 2121  140.000000  0.000000  0.006421  0.007426  0.000000  79.0   0.2  25.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  78.0   0.4  22.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  79.0   0.4  20.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  78.0   0.4  27.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  74.0   0.4  27.5
#
#       MLTV  Width  Tendency
# 0      2.4   64.0  0.999926
# ...

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2124.000000  2124.000000  2124.000000  2124.000000  2124.000000
# mean    133.288721     0.003133     0.001570     0.004365     0.001772
# std       9.926790     0.003830     0.002487     0.003001     0.002670
# min     105.000000    -0.008418    -0.003853    -0.005158    -0.004938
# 25%     126.000000     0.000000     0.000000     0.001858     0.000000
# 50%     133.000000     0.001634     0.000000     0.004486     0.000000
# 75%     140.000000     0.005612     0.002568     0.006536     0.003292
# max     161.000000     0.014030     0.006421     0.013552     0.008230
#
#               ASTV         MSTV         ALTV         MLTV        Width  \
# count  2124.000000  2124.000000  2124.000000  2124.000000  2124.000000
# mean     46.998334     1.304554     6.697979     8.002912    70.318547
# std      17.609911     0.781303    10.381254     5.046792    39.577385
# ...

# %% [markdown]
# ## 2.	Statistical Summary:

# %%
summary_stats = df.describe().T

summary_stats['median'] = df.median()
summary_stats['IQR'] = df.quantile(0.75) - df.quantile(0.25)


final_summary = summary_stats[['mean', 'median', 'std', 'IQR']]
final_summary
# Out:
#                 mean      median        std        IQR
# LB        133.288721  133.000000   9.926790  14.000000
# AC          0.003133    0.001634   0.003830   0.005612
# FM          0.001570    0.000000   0.002487   0.002568
# UC          0.004365    0.004486   0.003001   0.004678
# DL          0.001772    0.000000   0.002670   0.003292
# ASTV       46.998334   49.000000  17.609911  29.000000
# MSTV        1.304554    1.200000   0.781303   1.000000
# ALTV        6.697979    0.000000  10.381254  11.000000
# MLTV        8.002912    7.400000   5.046792   6.200000
# Width      70.318547   67.000000  39.577385  63.000000
# Tendency    0.316835    0.000000   0.622623   1.000000

# %% [markdown]
# ## 3.	Data Visualization:

# %%
for col in df:
    plt.figure()
    sns.histplot(df[col], kde=True)
    plt.title(f"Histogram of {col}")
    plt.show()

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
# Bar chart

plt.figure(figsize=(15, 5))
plt.bar(df['LB'],df['UC'])
plt.xlabel('LB')
plt.ylabel('UC')
# Out:
# Text(0, 0.5, 'UC')

# %%
df.corr()
# Out:
#                 LB        AC        FM        UC        DL      ASTV  \
# LB        1.000000 -0.081548 -0.006840 -0.163345 -0.156314  0.285464
# AC       -0.081548  1.000000  0.075611  0.093222 -0.103258 -0.273189
# FM       -0.006840  0.075611  1.000000 -0.318156 -0.018024  0.155798
# UC       -0.163345  0.093222 -0.318156  1.000000  0.268151 -0.217484
# DL       -0.156314 -0.103258 -0.018024  0.268151  1.000000 -0.112289
# ASTV      0.285464 -0.273189  0.155798 -0.217484 -0.112289  1.000000
# MSTV     -0.295132  0.216861  0.070412  0.298462  0.566625 -0.433731
# ALTV      0.322864 -0.408246 -0.013820 -0.294226 -0.296383  0.438800
# MLTV     -0.042241 -0.151713 -0.036439 -0.073152 -0.242345 -0.323930
# Width    -0.139978  0.283750  0.164178  0.131010  0.514238 -0.242111
# Tendency  0.281144  0.030489  0.000302 -0.074729  0.014025 -0.010237
#
#               MSTV      ALTV      MLTV     Width  Tendency
# LB       -0.295132  0.322864 -0.042241 -0.139978  0.281144
# ...

# %%
# Heatmap
plt.figure(figsize=(15,5))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
## Conclusion:

# %%
#MSTV and Width: 0.65
#DL and MSTV: 0.57
#DL and Width: 0.51
#MSTV and ALTV: -0.54

# Features like MSTV, Width, DL, and ALTV have meaningful correlations with others, so they may be more influential in predictive models.

# %%
# Pair plot
sns.pairplot(df)

# %% [markdown]
# ## 4.	Pattern Recognition and Insights:

# %%
correlation_value =df.corr()

print(correlation_value)
# Out:
#                 LB        AC        FM        UC        DL      ASTV  \
# LB        1.000000 -0.081669 -0.006815 -0.163308 -0.156278  0.285463
# AC       -0.081669  1.000000  0.076091  0.093575 -0.102934 -0.273178
# FM       -0.006815  0.076091  1.000000 -0.318156 -0.018024  0.155798
# UC       -0.163308  0.093575 -0.318156  1.000000  0.268151 -0.217484
# DL       -0.156278 -0.102934 -0.018024  0.268151  1.000000 -0.112289
# ASTV      0.285463 -0.273178  0.155798 -0.217484 -0.112289  1.000000
# MSTV     -0.295017  0.217933  0.070412  0.298462  0.566625 -0.433731
# ALTV      0.322748 -0.409829 -0.013820 -0.294226 -0.296383  0.438800
# MLTV     -0.042275 -0.152032 -0.036313 -0.072964 -0.242173 -0.323958
# Width    -0.140008  0.283771  0.164247  0.131110  0.514348 -0.242124
# Tendency  0.281361  0.029333  0.000673 -0.074266  0.014583 -0.010278
#
#               MSTV      ALTV      MLTV     Width  Tendency
# LB       -0.295017  0.322748 -0.042275 -0.140008  0.281361
# ...

# %% [markdown]
# ## 5.	Conclusion:

# %%
#The dataset appears to be clean with minimal missing values.

#Strong correlations among several variables (e.g.,MSTV and Width, MSTV–DL, Width–DL) indicate structured data.

#Highly correlated pairs (e.g., MSTV–DL: 0.566, UC–MSTV: 0.298) suggest possible multicollinearity, which should be addressed before modeling (e.g., using PCA or removing redundant variables).

#Some variables like ALTV and MSTV show negative correlations with others, indicating inverse relationships worth deeper exploration.

#The correlation of Tendency with other features is relatively weak, possibly making it an independent or noise variable.

#You may consider dropping or combining features with strong correlation (|r| > 0.8) to reduce redundancy and improve model interpretability.
